# %% [markdown]
# # **Importações**

# %%
from pandas import DataFrame, read_csv
import matplotlib.pyplot as plt
import pandas as pd
import sys
import matplotlib

# %matplotlib inline

# %%
print('Python version '+ sys.version)
print('Pandas Version '+ pd.__version__)
print('Matplotlib version '+ matplotlib.__version__)
# Out:
# Python version 3.6.9 (default, Nov  7 2019, 10:44:02)
# [GCC 8.3.0]
# Pandas Version 0.25.3
# Matplotlib version 3.1.3

# %% [markdown]
# # **Create Data**
#
# The data set will consist of 5 baby names and the number of births recorded for that year(1880).

# %%
names = ['Bob','Jessica','Mary','John','Mel']
births = [968,155,77,578,973]

# %% [markdown]
# To merge these two lists together we will use the zip function

# %%
zip?

# %%
BabyDataSet = list(zip(names,births))
BabyDataSet
# Out:
# [('Bob', 968), ('Jessica', 155), ('Mary', 77), ('John', 578), ('Mel', 973)]

# %% [markdown]
# We are basically done creating the data set. We now will use the pandas library to export this data set into a csv file.
#
# **df** will be a **DataFrame** object. You can think of this object holding the contents of the BabyDataSet in a format similar to a sql table or an excel spreadsheet. Lets take a look below at the contents inside **df**

# %%
df = pd.DataFrame(data = BabyDataSet, columns=['Names','Births'])
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %% [markdown]
# Export the dataframe to a csv file.
# we can name the file **births1880.csv**
# the function **to_csv** will be used to export the file.The file will be saved in the same location of the notebooks unless specified otherwise

# %%
df.to_csv?

# %% [markdown]
# The only parameters we will use is **index** and **header**. Setting these parameters to False will prevent the index and header names from being exported. Change the values of these parameters to get a better understading of their use.

# %%
df.to_csv('births1880.csv',index=False)

# %% [markdown]
# # **Get Data**
#
# To pull in the csv file, we will use the pandas *function* read_csv. Let us take a look at this function and what inputs it takes

# %%
read_csv?

# %%
Location = r'births1880.csv'
df = pd.read_csv(Location)

# %%
df
# Out:
#      Names  Births
# 0      Bob     968
# 1  Jessica     155
# 2     Mary      77
# 3     John     578
# 4      Mel     973

# %% [markdown]
# Deletando o arquivo csv

# %%
import os
os.remove(Location)

# %% [markdown]
# # **Prepare Data**

# %%
# Check data type of the columns
df.dtypes
# Out:
# Names     object
# Births     int64
# dtype: object

# %%
# Check data type of Births column
df.Births.dtype
# Out:
# dtype('int64')

# %% [markdown]
# # **Analyze Data**
#
# To find the most popular name or the baby name with the highest birth rate, we can do one of the following
#
#
# *   Sort the dataframe and select the top row
# *   Use the **max()** attribute to find the maximin value

# %%
# Method 1 
Sorted = df.sort_values(['Births'],ascending=False)
Sorted.head(1)
# Out:
#   Names  Births
# 4   Mel     973

# %%
#Method 2 
df['Births'].max()
# Out:
# 973

# %% [markdown]
# # **Present Data**

# %%
#Create Graph
df['Births'].plot()

#Maximun value in the data set
MaxValue = df['Births'].max()

#Name associate with the maximun value 
MaxName = df['Names'][df['Births'] == df['Births'].max()].values

#Text to display on graph 
Text = str(MaxValue) + " - "+ MaxName

# Add text to graph
plt.annotate(Text, xy=(1, MaxValue), xytext=(8, 0), 
                 xycoords=('axes fraction', 'data'), textcoords='offset points')

print("The most popular name")
df[df['Births'] == df['Births'].max()]
#Sorted.head(1) can also be used
# Out:
# The most popular name
#   Names  Births
# 4   Mel     973
