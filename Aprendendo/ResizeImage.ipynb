# %%
import cv2
from google.colab.patches import cv2_imshow

# %%
def resize(fname,width,height):
    img = cv2.imread(fname, cv2.IMREAD_UNCHANGED)
    cv2_imshow(img)
    org_height, org_width = image_shape[0:2]
    cv2.waitKey(0)

# %%
resize('formulario.png',120,960)
# Out:
# <PIL.Image.Image image mode=RGB size=1984x3696 at 0x7FCE3BA57828>
