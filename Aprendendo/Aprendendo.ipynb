# %%
import pandas as pd
import numpy as np

# %%
movies = pd.read_csv('movies.csv')
movies.head()
# Out:
#    movieId  ...                                       genres
# 0        1  ...  Adventure|Animation|Children|Comedy|Fantasy
# 1        2  ...                   Adventure|Children|Fantasy
# 2        3  ...                               Comedy|Romance
# 3        4  ...                         Comedy|Drama|Romance
# 4        5  ...                                       Comedy
#
# [5 rows x 3 columns]

# %%
links = pd.read_csv('links.csv')
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ratings = pd.read_csv('ratings.csv')
ratings
# Out:
#          userId  movieId  rating     timestamp
# 0             1      296     5.0  1.147880e+09
# 1             1      306     3.5  1.147869e+09
# 2             1      307     5.0  1.147869e+09
# 3             1      665     5.0  1.147879e+09
# 4             1      899     3.5  1.147869e+09
# ...         ...      ...     ...           ...
# 1144865    7721     1544     3.0  9.442212e+08
# 1144866    7721     1552     5.0  9.441464e+08
# 1144867    7721     1573     5.0  9.441464e+08
# 1144868    7721     1580     3.0  9.441459e+08
# 1144869    7721      158     NaN           NaN
#
# [1144870 rows x 4 columns]

# %%
tags = pd.read_csv('tags.csv')
tags
# Out:
#          userId  movieId                tag     timestamp
# 0             3      260            classic  1.439472e+09
# 1             3      260             sci-fi  1.439472e+09
# 2             4     1732        dark comedy  1.573944e+09
# 3             4     1732     great dialogue  1.573944e+09
# 4             4     7569   so bad it's good  1.573943e+09
# ...         ...      ...                ...           ...
# 1035787  155025     2527           suspense  1.167680e+09
# 1035788  155025     2572           romantic  1.167681e+09
# 1035789  155025     2572               teen  1.167681e+09
# 1035790  155025     2797  being a kid again  1.167681e+09
# 1035791  155025        2                NaN           NaN
#
# [1035792 rows x 4 columns]

# %%
joiningMovie = pd.merge(movies,links,on='movieId',how='inner')
joiningMovie.head()
# Out:
#    movieId                               title  ...  imdbId   tmdbId
# 0        1                    Toy Story (1995)  ...  114709    862.0
# 1        2                      Jumanji (1995)  ...  113497   8844.0
# 2        3             Grumpier Old Men (1995)  ...  113228  15602.0
# 3        4            Waiting to Exhale (1995)  ...  114885  31357.0
# 4        5  Father of the Bride Part II (1995)  ...  113041  11862.0
#
# [5 rows x 5 columns]

# %%
concat = pd.concat([ratings,tags],axis=1)
concat
# Out:
#          userId  movieId  rating  ...  movieId               tag     timestamp
# 0             1      296     5.0  ...    260.0           classic  1.439472e+09
# 1             1      306     3.5  ...    260.0            sci-fi  1.439472e+09
# 2             1      307     5.0  ...   1732.0       dark comedy  1.573944e+09
# 3             1      665     5.0  ...   1732.0    great dialogue  1.573944e+09
# 4             1      899     3.5  ...   7569.0  so bad it's good  1.573943e+09
# ...         ...      ...     ...  ...      ...               ...           ...
# 1144865    7721     1544     3.0  ...      NaN               NaN           NaN
# 1144866    7721     1552     5.0  ...      NaN               NaN           NaN
# 1144867    7721     1573     5.0  ...      NaN               NaN           NaN
# 1144868    7721     1580     3.0  ...      NaN               NaN           NaN
# 1144869    7721      158     NaN  ...      NaN               NaN           NaN
#
# [1144870 rows x 8 columns]
