# %% [markdown]
# # **3.5 Dados CSV**

# %%
import pandas as pd 
baseball_data = pd.read_csv('Master.csv',encoding='iso8859_2')

baseball_data.head()
# Out:
#    lahmanID   playerID managerID  ...   retroID    holtzID    bbrefID
# 0         1  aaronha01       NaN  ...  aaroh101  aaronha01  aaronha01
# 1         2  aaronto01       NaN  ...  aarot101  aaronto01  aaronto01
# 2         3   aasedo01       NaN  ...  aased001   aasedo01   aasedo01
# 3         4   abadan01       NaN  ...  abada001   abadan01   abadan01
# 4         5  abadijo01       NaN  ...  abadj101  abadijo01  abadijo01
#
# [5 rows x 33 columns]

# %%
baseball_data['height_plus_weight'] = \
  baseball_data['height'] + baseball_data['weight']
baseball_data[['height','weight','height_plus_weight']].head()
# Out:
#    height  weight  height_plus_weight
# 0    72.0   180.0               252.0
# 1    75.0   190.0               265.0
# 2    75.0   190.0               265.0
# 3    73.0   184.0               257.0
# 4    72.0   192.0               264.0

# %%
baseball_data.to_csv('baseball_data_with_weight_height.csv')
